# %% [markdown]
# # The langraph platform in the langsmith studio
#
# ![image.png](attachment:image.png)
#
# this is what i got after giving the iput in iput box and pressing submit button
#
# ![image-2.png](attachment:image-2.png)
#
# we can just simply press a button new thread
#
# ![image-3.png](attachment:image-3.png)
#
# it runs again
#
# ![image-4.png](attachment:image-4.png)
#
# and from here we can see history
#
# ![image-5.png](attachment:image-5.png)
#
# and it is very nice way to visualise the graph and track what is happening at which node in the threads
